# %%
import pandas as pd
import numpy as np
import glob
import json
import sklearn as sk
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
path = '/Users/jahankhan/CongressionalAppChallengePandemic/Research_Notebooks/cluster_concept'
metadata_path = f'{path}/metadata.csv'
#adds the path with the readable csv
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
# we are giving metadata to the datafram. This includes ifdes for papers
meta_df
# Out:
#         cord_uid                                       sha      source_x  \
# 0       ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb           PMC
# 1       02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d           PMC
# 2       ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927           PMC
# 3       2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605           PMC
# 4       9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32           PMC
# ...          ...                                       ...           ...
# 207306  25r1k6yb  1608fb53b337ea773004c388b6cb1cc5ac1e8e7b  Medline; PMC
# 207307  04d17ggn  e0344cab16912ac1eb3c55f8fc3edeb66e2d5b73  Medline; PMC
# 207308  7smnk0ob  38aa050ad79d8a1d7022c33535255ce9d47914e5  Medline; PMC
# 207309  6ptrilhm  59ea6e7a97e7f7ac235614568af7f598818179ac  Medline; PMC
# 207310  gq8mqfrv  d01ccc2773eb85cf5173842a708e6a374b4ef027  Medline; PMC
#
#                                                     title  \
# ...
